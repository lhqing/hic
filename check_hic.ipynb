# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR = '/home/hliu/data'
C_PCA_BED = os.path.join(DATA_DIR, 'proB-C-matrix', 'c.PCA.PC1.txt')
G_PCA_BED = os.path.join(DATA_DIR, 'proB-G-matrix', 'g.PCA.PC1.txt')
CORR_DIFF_BED = os.path.join(DATA_DIR, 'compare', 'c_vs_g.corrDiff.txt')
REGION_ANNO = os.path.join(DATA_DIR, 'compare', 'region.anno.25000.txt')

# %%
c_pca_bed_df = pd.read_table(C_PCA_BED, header=0, index_col=0)
g_pca_bed_df = pd.read_table(G_PCA_BED, header=0, index_col=0)
corr_diff_bed_df = pd.read_table(CORR_DIFF_BED, header=None, index_col=0, names=['ID', 'chr', 'start', 'end', 'strand', 'corrDiff'])
region_anno_df = pd.read_table(REGION_ANNO, header=0)

region_anno_df.head()
# Out:
#   PeakID (cmd=annotatePeaks.pl tss mm10 -gtf /home/hliu/ref/gencode.vM16.annotation.gtf -bedGraph /home/hliu/data/proB-C-matrix/c.PCA.PC1.bedGraph /home/hliu/data/proB-G-matrix/g.PCA.PC1.bedGraph)  \
# 0                               ENSMUST00000211605.1
# 1                              ENSMUST00000072186.11
# 2                               ENSMUST00000113027.7
# 3                               ENSMUST00000193674.1
# 4                               ENSMUST00000140492.1
#
#      Chr      Start        End Strand Not Used  Focus Ratio/Region Size  \
# 0  chr16   78263952   78267952      -        .                      NaN
# 1   chr2   37701275   37705275      -        .                      NaN
# 2   chrX  139561316  139565316      +        .                      NaN
# 3   chr1  136603468  136607468      -        .                      NaN
# 4   chr4   26344854   26348854      -        .                      NaN
#
# ...

# %%
c_pca_bed_df.head()
# Out:
#                  chr    start      end strand       PC1
# #peakID
# chr10-3075000  chr10  3075000  3100000      + -1.037146
# chr10-3100000  chr10  3100000  3125000      + -1.184111
# chr10-3125000  chr10  3125000  3150000      + -1.236512
# chr10-3150000  chr10  3150000  3175000      + -1.242293
# chr10-3175000  chr10  3175000  3200000      + -1.268675
