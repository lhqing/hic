# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

from random import shuffle
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
dirp = Path('/Users/hq/Documents/data/hic/')
df = pd.read_table(dirp / 'dn3' / 'DN3_Interactions_20K.txt', index_col=0)
df.head()
# Out:
#                     PeakID(1) chr(1)   start(1)     end(1) strand(1)  \
# InteractionID
# interaction1   chr2-167880000   chr2  167880000  167900000         +
# interaction2   chr8-126920000   chr8  126920000  126940000         +
# interaction3   chr13-52220000  chr13   52220000   52240000         +
# interaction4   chr7-143460000   chr7  143460000  143480000         +
# interaction5   chr10-22000000  chr10   22000000   22020000         +
#
#                Total Reads(1)       PeakID(2) chr(2)   start(2)     end(2)  \
# InteractionID
# interaction1           2156.0  chr2-167680000   chr2  167680000  167700000
# interaction2           1752.0  chr8-126480000   chr8  126480000  126500000
# interaction3           2166.0  chr13-51840000  chr13   51840000   51860000
# interaction4           1798.0  chr7-143140000   chr7  143140000  143160000
# interaction5           1386.0  chr10-21380000  chr10   21380000   21400000
#
#               strand(2)  Total Reads(2)  Distance  Interaction Reads  \
# InteractionID
# interaction1          +          2063.0    202961               99.0
# interaction2          +          2022.0    437007               67.0
# interaction3          +          2126.0    379749               61.0
# interaction4          +          2014.0    318487               60.0
# interaction5          +          1704.0    616781               43.0
#
#                Expected Reads   Z-score        LogP  \
# InteractionID
# interaction1         9.034123  3.250643 -152.153328
# interaction2         4.119315  3.203187 -128.070505
# interaction3         5.155698  2.904132  -98.491389
# interaction4         5.349958  2.925511  -94.088732
# interaction5         2.024511  3.360393  -93.779751
#
#                FDR(Benjamini, based on 9.27e+09 total tests)  Circos Thickness
# InteractionID
# interaction1                                             0.0                36
# interaction2                                             0.0                30
# interaction3                                             0.0                22
# interaction4                                             0.0                22
# interaction5                                             0.0                22

# %%
sns.jointplot(x='Distance', y='LogP', data=df)

sns.jointplot(x='Distance', y='Z-score', data=df)

# %%
# input homer significant interaction table, return intra interactions by chr

def merge_interaction(df, binsize, verbose=False, eps=0.001, min_samples=5):
    x = df['PeakID(1)'].apply(lambda i: int(i.split('-')[1]) // binsize)
    y = df['PeakID(2)'].apply(lambda i: int(i.split('-')[1]) // binsize)
    coord_df = pd.DataFrame([x, y]).T
    coord_df['chr(1)'] = df['chr(1)'][0]
    coord_df['chr(2)'] = df['chr(2)'][0]
    
    X = np.array(list(zip(x, y)))
    X = StandardScaler().fit_transform(X)
    db = DBSCAN(eps=eps, min_samples=min_samples).fit(X)
    labels = db.labels_
    
    if verbose:
        # Number of clusters in labels, ignoring noise if present.
        n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
        print('Estimated number of clusters in %s vs %s: %d' % 
              (df['chr(1)'][0], df['chr(2)'][0], n_clusters_))
    
    coord_df['cluster_dbscan'] = labels
    return coord_df


def merge_cluster(df):
    square_size = (df['PeakID(1)'].max() - df['PeakID(1)'].min() + 1) * \
                  (df['PeakID(2)'].max() - df['PeakID(2)'].min() + 1)
    real_interaction = df.shape[0]
    precent = real_interaction/square_size
    line = [[df['PeakID(1)'].min(), df['PeakID(1)'].max(), 
                          df['PeakID(2)'].min(), df['PeakID(2)'].max(),
                          real_interaction, square_size, precent]]
    if df['cluster_dbscan'][0] == -1:
        line = [[0, 0, 0, 0, 0, 0, 0]]
    return pd.DataFrame(line, columns=['peak1_start', 'peak1_end', 'peak2_start', 'peak2_end',
                                       'interactions', 'region_size', 'percentage'])


def merge_homer_inter_table(fp, binsize=20000, eps=0.001, min_samples=5):
    df_list = []
    df = pd.read_table(fp, index_col=0)
    cluster = df.groupby(['chr(1)', 'chr(2)']).apply(merge_interaction, binsize=binsize,
                                                     eps=eps, min_samples=min_samples)
    result = cluster.groupby(['chr(1)', 'chr(2)', 'cluster_dbscan']).apply(merge_cluster)
    result.reset_index(inplace=True)
    result.drop('level_3', inplace=True, axis=1)
    return result


dirp = Path('/Users/hq/Documents/data/hic/')
df = merge_homer_inter_table(dirp / 'dn3' / 'DN3_Interactions_20K.txt')

# %%
df
# Out:
#      chr(1) chr(2)  cluster_dbscan  peak1_start  peak1_end  peak2_start  \
# 0      chr1   chr1              -1            0          0            0
# 1      chr1   chr1               0         9101       9106         9090
# 2      chr1   chr1               1         6674       6684         6663
# 3      chr1   chr1               2         4279       4280         4262
# 4      chr1   chr1               3         4424       4443         4416
# 5      chr1   chr1               4         9015       9022         9012
# 6      chr1   chr1               5         7562       7573         7550
# 7      chr1   chr1               6         3211       3237         3181
# 8      chr1   chr1               7         2575       2580         2573
# 9      chr1   chr1               8         7754       7766         7750
# 10     chr1   chr1               9         1828       1839         1825
# 11     chr1   chr1              10         3242       3251         3231
# 12     chr1   chr1              11         8237       8264         8211
# 13     chr1   chr1              12         8304       8308         8284
# 14     chr1   chr1              13         3482       3491         3457
# 15     chr1   chr1              14         9159       9163         9152
# 16     chr1   chr1              15         6572       6580         6563
# 17     chr1   chr1              16         9005       9012         8989
# 18     chr1   chr1              17         1988       2002         1980
# 19     chr1   chr1              18         4346       4360         4329
# 20     chr1   chr1              19         1856       1874         1832
# 21     chr1   chr1              20         7680       7692         7673
# 22     chr1   chr1              21         1933       1943         1907
# 23     chr1   chr1              22          674        685          654
# 24     chr1   chr1              23         2784       2795         2762
# 25     chr1   chr1              24         6779       6787         6770
# 26     chr1   chr1              25         7749       7751         7737
# 27     chr1   chr1              26         6751       6756         6748
# 28     chr1   chr1              27         4311       4321         4303
# 29     chr1   chr1              28         2562       2575         2545
# ...     ...    ...             ...          ...        ...          ...
# 2999   chr9   chr9             213         4831       4833         4811
# 3000   chrX   chrX              -1            0          0            0
# 3001   chrX   chrX               0         2566       2569         2532
# 3002   chrX   chrX               1         7124       7126         7118
# 3003   chrX   chrX               2         5062       5068         5056
# 3004   chrX   chrX               3          679        684          660
# 3005   chrX   chrX               4         8359       8363         8330
# 3006   chrX   chrX               5         2415       2422         2399
# 3007   chrX   chrX               6         2425       2429         2399
# 3008   chrX   chrX               7         3670       3677         3649
# 3009   chrX   chrX               8          600        607          580
# 3010   chrX   chrX               9          620        626          580
# 3011   chrX   chrX              10         1818       1820         1810
# 3012   chrX   chrX              11         5123       5126         5108
# 3013   chrX   chrX              12         5368       5374         5338
# 3014   chrX   chrX              13         5355       5360         5337
# 3015   chrX   chrX              14         3693       3697         3689
# 3016   chrX   chrX              15          672        676          660
# 3017   chrX   chrX              16         4975       4982         4954
# 3018   chrX   chrX              17         3681       3683         3677
# 3019   chrX   chrX              18         3716       3721         3700
# 3020   chrX   chrX              19         2417       2419         2412
# 3021   chrX   chrX              20         5180       5182         5173
# 3022   chrX   chrX              21          399        403          395
# 3023   chrX   chrX              22         8195       8199         8145
# 3024   chrX   chrX              23         5334       5338         5328
# 3025   chrX   chrX              24         3717       3720         3712
# 3026   chrX   chrX              25         3680       3685         3650
# 3027   chrX   chrX              26         5195       5196         5170
# 3028   chrY   chrY              -1            0          0            0
#
#       peak2_end  interactions  region_size  percentage
# 0             0             0            0    0.000000
# 1          9102            33           78    0.423077
# 2          6676            47          154    0.305195
# 3          4264             5            6    0.833333
# 4          4432            85          340    0.250000
# 5          9018            22           56    0.392857
# 6          7558            43          108    0.398148
# 7          3203           112          621    0.180354
# 8          2576             9           24    0.375000
# 9          7758            36          117    0.307692
# 10         1831            30           84    0.357143
# 11         3239            31           90    0.344444
# 12         8230           134          560    0.239286
# 13         8293            15           50    0.300000
# 14         3466            34          100    0.340000
# 15         9156            10           25    0.400000
# 16         6568            23           54    0.425926
# 17         8996            31           64    0.484375
# 18         1990            59          165    0.357576
# 19         4338            50          150    0.333333
# 20         1853            90          418    0.215311
# 21         7681            29          117    0.247863
# 22         1920            40          154    0.259740
# 23          661            24           96    0.250000
# 24         2772            30          132    0.227273
# 25         6781            34          108    0.314815
# 26         7739             5            9    0.555556
# 27         6754            18           42    0.428571
# 28         4313            39          121    0.322314
# 29         2551            27           98    0.275510
# ...         ...           ...          ...         ...
# 2999       4813             6            9    0.666667
# 3000          0             0            0    0.000000
# 3001       2535             5           16    0.312500
# 3002       7120             5            9    0.555556
# 3003       5059             9           28    0.321429
# 3004        663             8           24    0.333333
# 3005       8334             7           25    0.280000
# 3006       2406            16           64    0.250000
# 3007       2401             6           15    0.400000
# 3008       3653            12           40    0.300000
# 3009        583             9           32    0.281250
# 3010        583            12           28    0.428571
# 3011       1812             7            9    0.777778
# 3012       5113             8           24    0.333333
# 3013       5344            12           49    0.244898
# 3014       5340            10           24    0.416667
# 3015       3692             8           20    0.400000
# 3016        665            10           30    0.333333
# 3017       4958            11           40    0.275000
# 3018       3680             6           12    0.500000
# 3019       3706            10           42    0.238095
# 3020       2414             5            9    0.555556
# 3021       5176             6           12    0.500000
# 3022        396             5           10    0.500000
# 3023       8147             5           15    0.333333
# 3024       5332             7           25    0.280000
# 3025       3715             7           16    0.437500
# 3026       3653             8           24    0.333333
# 3027       5174             5           10    0.500000
# 3028          0             0            0    0.000000
#
# [3029 rows x 10 columns]

# %%
chr_df = df[df['chr(1)'] == 'chr1']
colors = sns.color_palette("husl", chr_df['cluster_dbscan'].max() + 1)
shuffle(colors)

color_list = chr_df['cluster_dbscan'].apply(lambda i: colors[i] if i != -1 else (1,1,1))
scatter_df = pd.DataFrame([chr_df['PeakID(1)'], chr_df['PeakID(2)'], color_list], index=['x', 'y', 'color']).T
r_scatter_df = pd.DataFrame([chr_df['PeakID(2)'], chr_df['PeakID(1)'], color_list], index=['x', 'y', 'color']).T
scatter_df = pd.concat([scatter_df, r_scatter_df])

a, b = 4200, 4300
sub_scatter_df = scatter_df[(scatter_df['x'] > a) & (scatter_df['x'] < b) & 
                            (scatter_df['y'] > a) & (scatter_df['y'] < b)]
fig, ax=plt.subplots()
fig.set_size_inches(18, 18)
ax.scatter(sub_scatter_df['x'], sub_scatter_df['y'], c=sub_scatter_df['color'], s=10, marker="s")
plt.show()
